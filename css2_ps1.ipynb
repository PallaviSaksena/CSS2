# %% [markdown]
# # Block 1

# %%
# import libraries
import pandas as pd
from google.colab import files

# %% [markdown]
# # Block 2

# %%
# load data
files.upload()
data = pd.read_csv('problem_set_1_data.csv')

# rename columns
data = data.rename(columns={'quizzes': 'quiz_total', 'attendedClass': 'attended', 'finalgrade': 'final_grade', 'final_EXAM': 'final_exam', 'student': 'name'})

# print head, tail, and summary of df
print('------------ 2a ------------')
print(data.head())
print('------------ 2b ------------')
print(data.tail())
print('------------ 2c ------------')
print(data.describe())
# Out:
#      <input type="file" id="files-12e80967-9ff3-4456-91be-eccbb0341e37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12e80967-9ff3-4456-91be-eccbb0341e37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving problem_set_1_data.csv to problem_set_1_data (1).csv
# ------------ 2a ------------
#    quiz_total  attended  final_grade  final_exam               name
# 0       78.50         1        99.38          46       Linnie Lietz
# 1       64.25         0        95.78          45      Mitch Mustain
# 2       76.75         0        97.42          41     Salina Chavera
# 3       69.00         1        92.50          38  Kimberely Conwell
# 4       64.00         0        92.50          39          Zack Burk
# ------------ 2b ------------
# ...

# %% [markdown]
# Describe what the averages from the dataframe mean:
# * The averages refer to the average quizzes grades, final grades, and final exam grades of the class overall. The average quiz grade was a 69.13, the average final grade was a 91.85, and the average final exam score was a 39.67.

# %% [markdown]
# # Block 3

# %%
# subset data by whether someone attended class
#new_dfs = data.groupby(data.attended) 
#attended_df = new_dfs.get_group(1)
#did_not_attend_df = new_dfs.get_group(0)

boolean1 = data['attended'] == 1
boolean0 = data['attended'] == 0

print('------------ 3a ------------')
print(data[boolean1])
print('------------ 3b ------------')
print(data[boolean0])

# find average of quiz_total, final_grade, and final_exam for both subsets
print('------------ 3c ------------')
print(data[boolean1].describe())
print('------------ 3d ------------')
print(data[boolean0].describe())
# Out:
# ------------ 3a ------------
#      quiz_total  attended  final_grade  final_exam                 name
# 0         78.50         1        99.38          46         Linnie Lietz
# 3         69.00         1        92.50          38    Kimberely Conwell
# 5         63.00         1        89.38          36         Almeda Rizer
# 15        71.00         1        90.63          40          Mercy Dugal
# 16        77.00         1       101.25          46      Augustine Clair
# 27        75.00         1       101.25          45        Codi Whitcher
# 32        72.00         1        94.69          38           Nan Castro
# 36        73.00         1        87.81          33        Fern Iadarola
# 38        74.50         1        98.13          43        Delilah Starr
# 41        77.00         1       100.00          43         Maisie Monti
# 43        74.00         1        99.06          46        Shenna Tregre
# 44        68.00         1        89.38          35         Owen Meagher
# ...

# %% [markdown]
# Describe what you find about the averages:
# * The average quizzes grade for those who attended is 72.50,and for those who did not attend is 68.32.
# * The average final grade for those who attended is 95.07, and for those who did not attend is 91.08.
# * The average final exam score for those who attended is 40.63, and for those who did not attend is 39.44.
# For all three columns, the students who attended class had higher scores than the students who did not attend class.

# %% [markdown]
# # Block 4

# %%
# was anyone working together (e.g. they had the same scores)?
duplicate_scores = data.duplicated(subset=['quiz_total', 'final_grade', 'final_exam'], keep=False)
print('------------ 4a ------------')
print (duplicate_scores)

print('------------ 4b ------------')
print(data.loc[146])
print(data.loc[170])

print('------------ 4c ------------')
print(data.loc[146]['name'])
print(data.loc[170]['name'])
# Out:
# ------------ 4a ------------
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# ...
